# %% [markdown]
# Импортируем библиотеку
# Указываем локаию москву и парсим данные с 1 по 2 страницу.
# Сохраняем информацию по ней в файл "cian_data.csv"

# %%
import cianparser
import pandas as pd
import time

moscow = cianparser.CianParser(location='Москва')

data = []
for i in range(1, 2):
    a = moscow.get_flats(deal_type='sale', rooms=(1), additional_settings={'start_page': i, 'end_page':i} )
    data.extend(a)
    time.sleep(7)

exel_export = pd.DataFrame(data)
columns = ['author', 'author_type', 'location', 'deal_type', 'accommodation_type', 'floors_count', 'rooms_count', 'total_meters', 'price', 'district', 'street', 'house_number', 'underground', 'residential_complex']
selected_columns = exel_export[columns]
selected_columns.to_csv('cian_parsing.csv', mode='a', header=False, index=False)
# Out:
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 278 502 073 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.

# %% [markdown]
# Ипортируем библиотеку pandas

# %%
import pandas as pd

# %% [markdown]
# Составляем таблицу с информацией о квартирах

# %%
columns_names = ['author', 'author_type', 'location', 'deal_type', 'accommodation_type', 'floors_count', 'rooms_count', 'total_meters', 'price', 'district', 'street', 'house_number', 'underground', 'residential_complex']
df = pd.read_csv("cian_parsing.csv", on_bad_lines="skip", names=columns_names)
df
# Out:
#                  author        author_type location deal_type  \
# 0                Sminex          developer   Москва      sale
# 1           ID 12530791            unknown   Москва      sale
# 2       PROНЕДВИЖИМОСТЬ  real_estate_agent   Москва      sale
# 3                VESPER          developer   Москва      sale
# 4           ID 85604823            unknown   Москва      sale
# ...                 ...                ...      ...       ...
# 10602         SITRealty  real_estate_agent   Москва      sale
# 10603          MR Group          developer   Москва      sale
# 10604  Marry Lane Group  real_estate_agent   Москва      sale
# 10605          MR Group          developer   Москва      sale
# 10606            Sminex          developer   Москва      sale
#
#       accommodation_type  floors_count  rooms_count  total_meters  \
# 0                   flat            12            1         83.30
# 1                   flat            78            1         58.00
# 2                   flat            12            1         35.00
# 3                   flat             9            1         57.60
# 4                   flat            42            1         42.00
# ...                  ...           ...          ...           ...
# 10602               flat             7            1         47.50
# 10603               flat            49            1         39.37
# 10604               flat            44            1         48.10
# 10605               flat            46            1         34.80
# 10606               flat            14            1         72.60
#
#              price           district                        street  \
# 0      172590000.0          Хамовники        Фрунзенская набережная
# 1       58500000.0        Пресненский  1-й Красногвардейский проезд
# 2        9500000.0        Богородское              1-я Гражданская
# 3      117936000.0           Тверской          1-я Тверская-Ямская
# 4       29000000.0  Хорошево-Мневники      Шелепихинская набережная
# ...            ...                ...                           ...
# 10602   10100000.0                NaN                Медовая Долина
# 10603   19037954.0        Савеловский                           NaN
# 10604   25000000.0        Пресненский                    Ходынская
# 10605   16375836.0        Даниловский                           NaN
# 10606  139410000.0           Якиманка                           NaN
#
#       house_number             underground    residential_complex
# 0               30             Фрунзенская    Клубный город-парк
# 1             22с2             Москва-Сити            NEVA TOWERS
# 2             99К1  Преображенская площадь                    NaN
# 3                2              Маяковская       Vesper Tverskaya
# 4             34к5                Шелепиха         Сердце Столицы
# ...            ...                     ...                    ...
# 10602          1к2                  Санино  Баркли Медовая долина
# 10603          NaN             Дмитровская         Симфония 34 ЖК
# 10604            2         Улица 1905 года            Пресня Сити
# 10605          NaN              Павелецкая     Павелецкая Сити ЖК
# 10606          NaN                 Полянка        Лаврушинский ЖК
#
# [10607 rows x 14 columns]

# %%
df
# Out:
#                   author        author_type location deal_type  \
# 0                 Sminex          developer   Москва      sale
# 1            ID 12530791            unknown   Москва      sale
# 3                 VESPER          developer   Москва      sale
# 4            ID 85604823            unknown   Москва      sale
# 5          ХОРЕКА ИНВЕСТ  real_estate_agent   Москва      sale
# ...                  ...                ...      ...       ...
# 10595     Павел Михайлов            realtor   Москва      sale
# 10597  Sense Development          developer   Москва      sale
# 10598             hoomie  real_estate_agent   Москва      sale
# 10601   Владислав Карпов            realtor   Москва      sale
# 10604   Marry Lane Group  real_estate_agent   Москва      sale
#
#       accommodation_type  floors_count  rooms_count  total_meters  \
# 0                   flat            12            1         83.30
# 1                   flat            78            1         58.00
# 3                   flat             9            1         57.60
# 4                   flat            42            1         42.00
# 5                   flat            21            1         21.66
# ...                  ...           ...          ...           ...
# 10595               flat            16            1         44.00
# 10597               flat            13            1         58.80
# 10598               flat            20            1         43.09
# 10601               flat            28            1         40.00
# 10604               flat            44            1         48.10
#
#              price            district                        street  \
# 0      172590000.0           Хамовники        Фрунзенская набережная
# 1       58500000.0         Пресненский  1-й Красногвардейский проезд
# 3      117936000.0            Тверской          1-я Тверская-Ямская
# 4       29000000.0   Хорошево-Мневники      Шелепихинская набережная
# 5        5500000.0  Тропарево-Никулино           Востряковское шоссе
# ...            ...                 ...                           ...
# 10595   26296000.0             Раменки    проспект Генерала Дорохова
# 10597   37642247.0         Даниловский               Даниловский Вал
# 10598   20252300.0         Даниловский                Автозаводская
# 10601   30500000.0             Раменки                    Винницкая
# 10604   25000000.0         Пресненский                    Ходынская
#
#       house_number      underground                 residential_complex
# 0               30      Фрунзенская                 Клубный город-парк
# 1             22с2      Москва-Сити                         NEVA TOWERS
# 3                2       Маяковская                    Vesper Tverskaya
# 4             34к5         Шелепиха                      Сердце Столицы
# 5              7с3          Озёрная       Комплекс апартаментов CITIMIX
# ...            ...              ...                                 ...
# 10595        39к2Л          Минская  Собрание клубных домов West Garden
# 10597           1А         Тульская                               Logos
# 10598           26         Тульская                               FORST
# 10601          8к3          Раменки                           Настоящее
# 10604            2  Улица 1905 года                         Пресня Сити
#
# [874 rows x 14 columns]

# %%
def take_info_from_list(val_list):
    val_str = ', '
    if len(val_list) == 0:
        return 'Нету информации'
    else:
        return val_str.join(val_list)

# %%
df
# Out:
#                   author        author_type location deal_type  \
# 0                 Sminex          developer   Москва      sale
# 1            ID 12530791            unknown   Москва      sale
# 3                 VESPER          developer   Москва      sale
# 4            ID 85604823            unknown   Москва      sale
# 5          ХОРЕКА ИНВЕСТ  real_estate_agent   Москва      sale
# ...                  ...                ...      ...       ...
# 10595     Павел Михайлов            realtor   Москва      sale
# 10597  Sense Development          developer   Москва      sale
# 10598             hoomie  real_estate_agent   Москва      sale
# 10601   Владислав Карпов            realtor   Москва      sale
# 10604   Marry Lane Group  real_estate_agent   Москва      sale
#
#       accommodation_type  floors_count  rooms_count  total_meters  \
# 0                   flat            12            1         83.30
# 1                   flat            78            1         58.00
# 3                   flat             9            1         57.60
# 4                   flat            42            1         42.00
# 5                   flat            21            1         21.66
# ...                  ...           ...          ...           ...
# 10595               flat            16            1         44.00
# 10597               flat            13            1         58.80
# 10598               flat            20            1         43.09
# 10601               flat            28            1         40.00
# 10604               flat            44            1         48.10
#
#              price            district                        street  \
# 0      172590000.0           Хамовники        Фрунзенская набережная
# 1       58500000.0         Пресненский  1-й Красногвардейский проезд
# 3      117936000.0            Тверской          1-я Тверская-Ямская
# 4       29000000.0   Хорошево-Мневники      Шелепихинская набережная
# 5        5500000.0  Тропарево-Никулино           Востряковское шоссе
# ...            ...                 ...                           ...
# 10595   26296000.0             Раменки    проспект Генерала Дорохова
# 10597   37642247.0         Даниловский               Даниловский Вал
# 10598   20252300.0         Даниловский                Автозаводская
# 10601   30500000.0             Раменки                    Винницкая
# 10604   25000000.0         Пресненский                    Ходынская
#
#       house_number      underground                 residential_complex
# 0               30      Фрунзенская                 Клубный город-парк
# 1             22с2      Москва-Сити                         NEVA TOWERS
# 3                2       Маяковская                    Vesper Tverskaya
# 4             34к5         Шелепиха                      Сердце Столицы
# 5              7с3          Озёрная       Комплекс апартаментов CITIMIX
# ...            ...              ...                                 ...
# 10595        39к2Л          Минская  Собрание клубных домов West Garden
# 10597           1А         Тульская                               Logos
# 10598           26         Тульская                               FORST
# 10601          8к3          Раменки                           Настоящее
# 10604            2  Улица 1905 года                         Пресня Сити
#
# [874 rows x 14 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of                   author        author_type location deal_type  \
# 0                 Sminex          developer   Москва      sale
# 1            ID 12530791            unknown   Москва      sale
# 3                 VESPER          developer   Москва      sale
# 4            ID 85604823            unknown   Москва      sale
# 5          ХОРЕКА ИНВЕСТ  real_estate_agent   Москва      sale
# ...                  ...                ...      ...       ...
# 10595     Павел Михайлов            realtor   Москва      sale
# 10597  Sense Development          developer   Москва      sale
# 10598             hoomie  real_estate_agent   Москва      sale
# 10601   Владислав Карпов            realtor   Москва      sale
# 10604   Marry Lane Group  real_estate_agent   Москва      sale
#
#       accommodation_type  floors_count  rooms_count  total_meters  \
# 0                   flat            12            1         83.30
# 1                   flat            78            1         58.00
# 3                   flat             9            1         57.60
# 4                   flat            42            1         42.00
# 5                   flat            21            1         21.66
# ...                  ...           ...          ...           ...
# 10595               flat            16            1         44.00
# 10597               flat            13            1         58.80
# 10598               flat            20            1         43.09
# 10601               flat            28            1         40.00
# 10604               flat            44            1         48.10
#
#              price            district                        street  \
# 0      172590000.0           Хамовники        Фрунзенская набережная
# 1       58500000.0         Пресненский  1-й Красногвардейский проезд
# 3      117936000.0            Тверской          1-я Тверская-Ямская
# 4       29000000.0   Хорошево-Мневники      Шелепихинская набережная
# 5        5500000.0  Тропарево-Никулино           Востряковское шоссе
# ...            ...                 ...                           ...
# 10595   26296000.0             Раменки    проспект Генерала Дорохова
# 10597   37642247.0         Даниловский               Даниловский Вал
# 10598   20252300.0         Даниловский                Автозаводская
# 10601   30500000.0             Раменки                    Винницкая
# 10604   25000000.0         Пресненский                    Ходынская
#
#       house_number      underground                 residential_complex
# 0               30      Фрунзенская                 Клубный город-парк
# 1             22с2      Москва-Сити                         NEVA TOWERS
# 3                2       Маяковская                    Vesper Tverskaya
# 4             34к5         Шелепиха                      Сердце Столицы
# 5              7с3          Озёрная       Комплекс апартаментов CITIMIX
# ...            ...              ...                                 ...
# 10595        39к2Л          Минская  Собрание клубных домов West Garden
# 10597           1А         Тульская                               Logos
# 10598           26         Тульская                               FORST
# 10601          8к3          Раменки                           Настоящее
# 10604            2  Улица 1905 года                         Пресня Сити
#
# [874 rows x 14 columns]>

# %%
df.describe()
# Out:
#        floors_count  rooms_count  total_meters         price
# count    874.000000   874.000000    874.000000  8.740000e+02
# mean      24.736842     1.622426     58.877185  4.389781e+07
# std       16.359558     0.487414     25.357401  4.811767e+07
# min        3.000000     1.000000     19.900000  5.500000e+06
# 25%       14.000000     1.000000     42.000000  1.950000e+07
# 50%       21.000000     2.000000     53.225000  2.900000e+07
# 75%       30.000000     2.000000     68.425000  4.900000e+07
# max       97.000000     3.000000    229.000000  5.823300e+08

# %%
df = df.dropna()

# %% [markdown]
# Имортируем билиотеки для составления графиков

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# Составляем таблицу с названием "Распредление цен"
# Частота на цену

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['price'], bins=30, kde=True)
plt.title('Распределение цен')
plt.xlabel('Цена')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# Составляем таблицу с названием "Распределение площади"
# Частота на Площадь.

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['total_meters'], bins=30, kde=True)
plt.title('Распределение площади')
plt.xlabel('Площадь (м²)')
plt.ylabel('Частота')
plt.show()

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Корреляции между числовыми переменными')
plt.show()

# %%
plt.figure(figsize=(24, 12))
sns.countplot(data=df, x='district', order=df['district'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Количество объектов в разных районах')
plt.xlabel('Район')
plt.ylabel('Количество объектов')
plt.show()
# Out:
# ) missing from font(s) DejaVu Sans.нг\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='total_meters', y='price')
plt.title('Зависимость цены от площади')
plt.xlabel('Площадь (м²)')
plt.ylabel('Цена')
plt.show()

# %%
avg_price_per_district = df.groupby('district')['price'].mean().sort_values()
plt.figure(figsize=(24, 12))
avg_price_per_district.plot(kind='bar')
plt.title('Средняя цена по районам')
plt.xlabel('Район')
plt.ylabel('Средняя цена')
plt.show()
# Out:
# ) missing from font(s) DejaVu Sans.нг\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)
